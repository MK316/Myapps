# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Myapps/blob/main/IPA_practice_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IPA Practice Application(0919)

# %% [markdown]
# # Without user name

# %%
# !pip install gradio

# %%
#@markdown This app works, asking only once for each IPA
import pandas as pd
import random
import gradio as gr

# Load the CSV data from the provided URL
def load_data():
    url = "https://raw.githubusercontent.com/MK316/Myapps/main/data/IPA.csv"
    return pd.read_csv(url, encoding='utf-8')

df = load_data()  # Load data once at the start

# Properties to ask about for each IPA symbol
properties = ['Voicing', 'Place', 'Centrality', 'Oro-nasal', 'Manner']

# Track used IPA symbols to avoid repetition
used_ipa_symbols = []

def generate_question(current_ipa, current_property_index):
    ipa_symbol = current_ipa['IPA']
    property_name = properties[current_property_index]
    question = f"IPA Symbol: {ipa_symbol}\nWhat is the {property_name.lower()} of this IPA symbol?"
    answer = current_ipa[property_name].lower()
    return question, answer, property_name.lower()

def quiz_function(user_answer, score, trials, question_info, current_property_index):
    correct_answer = question_info['answer']
    property_name = question_info['property']

    # Check the answer
    if user_answer.lower() == correct_answer:
        score[0] += 1
        result = f"Correct! The {property_name} is '{correct_answer}'."
    else:
        result = f"Wrong! The correct {property_name} was '{correct_answer}'."

    # Increment the trial count
    trials[0] += 1

    # Update the property index to ask the next property
    current_property_index += 1

    # Check if we have asked all properties for the current IPA
    if current_property_index >= len(properties):
        # Select a new IPA symbol, ensuring it hasn't been used before
        if len(used_ipa_symbols) >= len(df):
            # All IPA symbols have been used, reset the used symbols list
            used_ipa_symbols.clear()

        # Pick a new IPA symbol that hasn't been used
        while True:
            current_ipa = df.sample(1).iloc[0]
            if current_ipa['IPA'] not in used_ipa_symbols:
                used_ipa_symbols.append(current_ipa['IPA'])  # Mark this IPA as used
                break

        current_property_index = 0  # Reset the property index for the new IPA
    else:
        # Continue asking for the next property of the same IPA
        current_ipa = question_info['current_ipa']

    # Generate the next question for the current or new IPA symbol
    new_question, new_answer, new_property = generate_question(current_ipa, current_property_index)
    question_info.update({
        'question': new_question,
        'answer': new_answer,
        'property': new_property,
        'current_ipa': current_ipa
    })

    # Return result, next question, current score/trials, and updated property index
    return f"{result} Total points: {score[0]}/{trials[0]}.", question_info['question'], current_property_index

def gradio_interface():
    score = [0]  # Track the user's score
    trials = [0]  # Track the number of trials (questions asked)
    current_property_index = [0]  # Track which property we are asking about
    question_info = {'question': '', 'answer': '', 'property': '', 'current_ipa': None}

    def initialize_quiz():
        # Select a new IPA symbol and mark it as used
        current_ipa = df.sample(1).iloc[0]
        used_ipa_symbols.append(current_ipa['IPA'])
        question_info['question'], question_info['answer'], question_info['property'] = generate_question(current_ipa, 0)
        question_info['current_ipa'] = current_ipa
        current_property_index[0] = 0  # Start from the first property
        return question_info['question'], "", current_property_index[0]

    def submit_answer(user_answer):
        result, question, updated_property_index = quiz_function(user_answer, score, trials, question_info, current_property_index[0])
        current_property_index[0] = updated_property_index  # Update the property index
        return result, question, ""

    def quit_quiz():
        # Return only one output to avoid displaying 'None'
        return f"Quiz ended. Your total score: {score[0]}/{trials[0]} points."

    # Now defining all the components inside the Blocks context properly
    with gr.Blocks() as app:
        with gr.Column():  # Column to ensure all elements are aligned vertically
            question_label = gr.Textbox(label="Question", interactive=False)
            answer_input = gr.Textbox(label="Your Answer", placeholder="Type your answer here")

            submit_button = gr.Button("Submit")  # Submit button comes right after the answer input

            output_label = gr.Textbox(label="Result", interactive=False)  # Result comes after the submit button

            quit_button = gr.Button("Quit")  # Quit button stays at the end

        # Handle the submit answer action
        submit_button.click(fn=submit_answer, inputs=[answer_input], outputs=[output_label, question_label, answer_input])

        # Handle the quit action (now only returning one output)
        quit_button.click(fn=quit_quiz, outputs=[output_label])

        # Initialize the first question
        question_label.value, _, _ = initialize_quiz()

    return app

app = gradio_interface()
app.launch()

# %% [markdown]
# # With name

# %%
import pandas as pd
import random
import gradio as gr

def load_data():
    url = "https://raw.githubusercontent.com/MK316/Myapps/main/data/IPA.csv"
    return pd.read_csv(url, encoding='utf-8')

df = load_data()

properties = ['Voicing', 'Place', 'Centrality', 'Oro-nasal', 'Manner']
used_ipa_symbols = []

def generate_question():
    current_ipa = df.sample(1).iloc[0]
    while current_ipa['IPA'] in used_ipa_symbols:
        current_ipa = df.sample(1).iloc[0]
    used_ipa_symbols.append(current_ipa['IPA'])
    current_property_index = random.randint(0, len(properties) - 1)
    property_name = properties[current_property_index]
    question = f"IPA Symbol: {current_ipa['IPA']}\nWhat is the {property_name.lower()} of this IPA symbol?"
    answer = current_ipa[property_name].lower()
    return question, answer, current_property_index

def quiz_function(user_answer, score, trials, correct_answer):
    if user_answer.lower() == correct_answer:
        score[0] += 1
        result = f"Correct! The answer was '{correct_answer}'."
    else:
        result = f"Wrong! The correct answer was '{correct_answer}'."
    trials[0] += 1
    return result

def gradio_interface():
    score = [0]
    trials = [0]
    question_info = {'question': '', 'answer': '', 'property_index': 0}
    user_name = ['']  # Use a list to hold the user name to persist changes

    def start_quiz(name):
        user_name[0] = name  # Store the user's name
        question, answer, property_index = generate_question()
        question_info.update({'question': question, 'answer': answer, 'property_index': property_index})
        return question

    def submit_answer(user_answer):
        result = quiz_function(user_answer, score, trials, question_info['answer'])
        new_question, new_answer, new_property_index = generate_question()
        question_info.update({'question': new_question, 'answer': new_answer, 'property_index': new_property_index})
        return result, new_question

    def quit_quiz():
        # Use the user's name stored in user_name list
        return f"Quiz ended. Well done, {user_name[0]}! Your total score: {score[0]}/{trials[0]} points."

    with gr.Blocks() as app:
        with gr.Column():
            name_input = gr.Textbox(label="Enter your name", placeholder="Your name")
            start_button = gr.Button("Start Quiz")
            question_label = gr.Textbox(label="Question", interactive=False)
            answer_input = gr.Textbox(label="Your Answer", placeholder="Type your answer here")
            submit_button = gr.Button("Submit")
            output_label = gr.Textbox(label="Result", interactive=False)
            quit_button = gr.Button("Quit")

            start_button.click(fn=start_quiz, inputs=[name_input], outputs=[question_label])
            submit_button.click(fn=submit_answer, inputs=[answer_input], outputs=[output_label, question_label])
            quit_button.click(fn=quit_quiz, outputs=[output_label])

    return app

app = gradio_interface()
app.launch()

# %% [markdown]
# # Variable issues: mixed user names when sharing †he session, and answer key mixup

# %%
# !pip install gradio

# %%
import pandas as pd
import random
import gradio as gr

# Load the CSV data
def load_data():
    url = "https://raw.githubusercontent.com/MK316/Myapps/main/data/IPA.csv"
    try:
        data = pd.read_csv(url, encoding='utf-8')
        if 'IPA' not in data.columns:
            raise ValueError("The required 'IPA' column is missing in the data.")
        return data
    except Exception as e:
        raise ValueError(f"Error loading data: {e}")

df = load_data()

# Properties to ask about for each IPA symbol
properties = ['Voicing', 'Place', 'Centrality', 'Oro-nasal', 'Manner']

# Generate a new question
def generate_question(used_ipa_symbols):
    if df.empty or 'IPA' not in df.columns:
        raise ValueError("IPA data is not loaded properly or missing.")

    # Ensure `used_ipa_symbols` is never None
    if used_ipa_symbols is None:
        used_ipa_symbols = []

    # Loop until we get a valid IPA symbol that hasn't been used yet
    current_ipa = df.sample(1).iloc[0]
    while pd.isnull(current_ipa['IPA']) or current_ipa['IPA'] in used_ipa_symbols:
        current_ipa = df.sample(1).iloc[0]

    used_ipa_symbols.append(current_ipa['IPA'])
    property_name = random.choice(properties)

    # Ensure valid property values before creating the question
    if pd.isnull(current_ipa[property_name]):
        raise ValueError(f"Missing data for property {property_name}")

    question = f"IPA Symbol: {current_ipa['IPA']}\nWhat is the {property_name.lower()} of this IPA symbol?"
    answer = current_ipa[property_name].lower()
    return question, answer, used_ipa_symbols

# Check the answer and update the score and trials
def quiz_function(user_answer, score, trials, correct_answer):
    if user_answer.lower() == correct_answer:
        score += 1
        result = f"Correct! The answer was '{correct_answer}'."
    else:
        result = f"Wrong! The correct answer was '{correct_answer}'."
    trials += 1
    return result, score, trials

# Define the Gradio interface
def gradio_interface():
    def start_quiz(name):
        # Initialize user-specific variables
        score = 0
        trials = 0
        used_ipa_symbols = []

        # Generate the first question for the user
        try:
            question, answer, used_ipa_symbols = generate_question(used_ipa_symbols)
        except ValueError as e:
            return str(e), gr.State(), gr.State(), gr.State(), gr.State()

        return question, gr.State(answer), gr.State(used_ipa_symbols), gr.State(score), gr.State(trials)

    def submit_answer(user_answer, answer, used_ipa_symbols, score, trials):
        # Ensure that score and trials are integers
        if score is None:
            score = 0
        if trials is None:
            trials = 0
        if used_ipa_symbols is None:
            used_ipa_symbols = []

        # Check answer and update score and trials
        result, updated_score, updated_trials = quiz_function(user_answer, score, trials, answer)

        # Generate the next question
        try:
            new_question, new_answer, used_ipa_symbols = generate_question(used_ipa_symbols)
        except ValueError as e:
            return str(e), "", gr.State(), gr.State(), gr.State(), gr.State()

        return result, new_question, gr.State(new_answer), gr.State(used_ipa_symbols), gr.State(updated_score), gr.State(updated_trials)

    def quit_quiz(user_name, score, trials):
        # Display the final message with the user's name and score
        if score is None:
            score = 0
        if trials is None:
            trials = 0
        return f"Quiz ended. Well done, {user_name}! Your total score: {score}/{trials} points."

    # Gradio interface setup
    with gr.Blocks() as app:
        with gr.Column():
            # Components for user interaction
            name_input = gr.Textbox(label="Enter your name", placeholder="Your name")
            start_button = gr.Button("Start Quiz")
            question_label = gr.Textbox(label="Question", interactive=False)
            answer_input = gr.Textbox(label="Your Answer", placeholder="Type your answer here")
            submit_button = gr.Button("Submit")
            output_label = gr.Textbox(label="Result", interactive=False)
            quit_button = gr.Button("Quit")

            # Button click actions
            start_button.click(
                fn=start_quiz,
                inputs=[name_input],
                outputs=[question_label, gr.State(), gr.State(), gr.State(), gr.State()]
            )
            submit_button.click(
                fn=submit_answer,
                inputs=[answer_input, gr.State(), gr.State(), gr.State(), gr.State()],
                outputs=[output_label, question_label, gr.State(), gr.State(), gr.State(), gr.State()]
            )
            quit_button.click(
                fn=quit_quiz,
                inputs=[name_input, gr.State(), gr.State()],
                outputs=[output_label]
            )

    return app

app = gradio_interface()
app.launch()

# %%
import pandas as pd
import random
import gradio as gr

# Load the CSV data
def load_data():
    url = "https://raw.githubusercontent.com/MK316/Myapps/main/data/IPA.csv"
    try:
        data = pd.read_csv(url, encoding='utf-8')
        if 'IPA' not in data.columns:
            raise ValueError("The required 'IPA' column is missing in the data.")
        return data
    except Exception as e:
        raise ValueError(f"Error loading data: {e}")

df = load_data()

# Properties to ask about for each IPA symbol
properties = ['Voicing', 'Place', 'Centrality', 'Oro-nasal', 'Manner']

# Generate a new question
def generate_question(used_ipa_symbols):
    if df.empty or 'IPA' not in df.columns:
        raise ValueError("IPA data is not loaded properly or missing.")

    # Loop until we get a valid IPA symbol that hasn't been used yet
    current_ipa = df.sample(1).iloc[0]
    while pd.isnull(current_ipa['IPA']) or current_ipa['IPA'] in used_ipa_symbols:
        current_ipa = df.sample(1).iloc[0]

    used_ipa_symbols.append(current_ipa['IPA'])
    property_name = random.choice(properties)

    # Ensure valid property values before creating the question
    if pd.isnull(current_ipa[property_name]):
        raise ValueError(f"Missing data for property {property_name}")

    question = f"IPA Symbol: {current_ipa['IPA']}\nWhat is the {property_name.lower()} of this IPA symbol?"
    answer = current_ipa[property_name].lower()
    return question, answer, used_ipa_symbols

# Check the answer and update the score and trials
def quiz_function(user_answer, correct_answer, score, trials):
    if user_answer.lower() == correct_answer:
        score += 1
        result = f"Correct! The answer was '{correct_answer}'."
    else:
        result = f"Wrong! The correct answer was '{correct_answer}'."
    trials += 1
    return result, score, trials

# Define the Gradio interface
def gradio_interface():
    def start_quiz(name):
        # Initialize user-specific variables
        score = 0
        trials = 0
        used_ipa_symbols = []

        # Generate the first question for the user
        try:
            question, answer, used_ipa_symbols = generate_question(used_ipa_symbols)
        except ValueError as e:
            return str(e), None, None, None, None

        return question, answer, used_ipa_symbols, score, trials

    def submit_answer(user_answer, answer, used_ipa_symbols, score, trials):
        # Ensure that score and trials are integers
        if score is None:
            score = 0
        if trials is None:
            trials = 0
        if used_ipa_symbols is None:
            used_ipa_symbols = []

        # Check the answer and update score and trials
        result, updated_score, updated_trials = quiz_function(user_answer, answer, score, trials)

        # Generate the next question
        try:
            new_question, new_answer, used_ipa_symbols = generate_question(used_ipa_symbols)
        except ValueError as e:
            return str(e), "", None, None, None

        return result, new_question, new_answer, used_ipa_symbols, updated_score, updated_trials

    def quit_quiz(user_name, score, trials):
        # Display the final message with the user's name and score
        if score is None:
            score = 0
        if trials is None:
            trials = 0
        return f"Quiz ended. Well done, {user_name}! Your total score: {score}/{trials} points."

    # Gradio interface setup
    with gr.Blocks() as app:
        with gr.Column():
            # Components for user interaction
            name_input = gr.Textbox(label="Enter your name", placeholder="Your name")
            start_button = gr.Button("Start Quiz")
            question_label = gr.Textbox(label="Question", interactive=False)
            answer_input = gr.Textbox(label="Your Answer", placeholder="Type your answer here")
            submit_button = gr.Button("Submit")
            output_label = gr.Textbox(label="Result", interactive=False)
            quit_button = gr.Button("Quit")

            # Button click actions
            start_button.click(
                fn=start_quiz,
                inputs=[name_input],
                outputs=[question_label, gr.State(), gr.State(), gr.State(), gr.State()]
            )
            submit_button.click(
                fn=submit_answer,
                inputs=[answer_input, gr.State(), gr.State(), gr.State(), gr.State()],
                outputs=[output_label, question_label, gr.State(), gr.State(), gr.State()]
            )
            quit_button.click(
                fn=quit_quiz,
                inputs=[name_input, gr.State(), gr.State()],
                outputs=[output_label]
            )

    return app

app = gradio_interface()
app.launch()

# %%
import pandas as pd
import random
import gradio as gr

# Load the CSV data
def load_data():
    url = "https://raw.githubusercontent.com/MK316/Myapps/main/data/IPA.csv"
    try:
        data = pd.read_csv(url, encoding='utf-8')
        if 'IPA' not in data.columns:
            raise ValueError("The required 'IPA' column is missing in the data.")
        return data
    except Exception as e:
        raise ValueError(f"Error loading data: {e}")

df = load_data()

# Properties to ask about for each IPA symbol
properties = ['Voicing', 'Place', 'Centrality', 'Oro-nasal', 'Manner']

# Generate a new question
def generate_question(used_ipa_symbols):
    if df.empty or 'IPA' not in df.columns:
        raise ValueError("IPA data is not loaded properly or missing.")

    # Ensure `used_ipa_symbols` is never None
    if used_ipa_symbols is None:
        used_ipa_symbols = []

    # Loop until we get a valid IPA symbol that hasn't been used yet
    current_ipa = df.sample(1).iloc[0]
    while pd.isnull(current_ipa['IPA']) or current_ipa['IPA'] in used_ipa_symbols:
        current_ipa = df.sample(1).iloc[0]

    used_ipa_symbols.append(current_ipa['IPA'])

    # Select a property that has valid data
    available_properties = [prop for prop in properties if not pd.isnull(current_ipa[prop])]
    if not available_properties:
        raise ValueError(f"No valid properties available for IPA symbol {current_ipa['IPA']}.")

    property_name = random.choice(available_properties)

    question = f"IPA Symbol: {current_ipa['IPA']}\nWhat is the {property_name.lower()} of this IPA symbol?"
    answer = current_ipa[property_name].lower()
    return question, answer, used_ipa_symbols

# Check the answer and update the score and trials
def quiz_function(user_answer, correct_answer, score, trials):
    if user_answer.lower() == correct_answer:
        score += 1
        result = f"Correct! The answer was '{correct_answer}'."
    else:
        result = f"Wrong! The correct answer was '{correct_answer}'."
    trials += 1
    return result, score, trials

# Define the Gradio interface
def gradio_interface():
    def start_quiz(name):
        # Initialize user-specific variables
        score = 0
        trials = 0
        used_ipa_symbols = []

        # Generate the first question for the user
        try:
            question, answer, used_ipa_symbols = generate_question(used_ipa_symbols)
        except ValueError as e:
            return str(e), answer, used_ipa_symbols, score, trials

        return question, answer, used_ipa_symbols, score, trials

    def submit_answer(user_answer, answer, used_ipa_symbols, score, trials):
        # Ensure that score and trials are integers
        if score is None:
            score = 0
        if trials is None:
            trials = 0
        if used_ipa_symbols is None:
            used_ipa_symbols = []

        # Check the answer and update score and trials
        result, updated_score, updated_trials = quiz_function(user_answer, answer, score, trials)

        # Generate the next question
        try:
            new_question, new_answer, used_ipa_symbols = generate_question(used_ipa_symbols)
        except ValueError as e:
            return str(e), new_question, new_answer, used_ipa_symbols, updated_score, updated_trials

        return result, new_question, new_answer, used_ipa_symbols, updated_score, updated_trials

    def quit_quiz(user_name, score, trials):
        # Display the final message with the user's name and score
        if score is None:
            score = 0
        if trials is None:
            trials = 0
        return f"Quiz ended. Well done, {user_name}! Your total score: {score}/{trials} points."

    # Gradio interface setup
    with gr.Blocks() as app:
        with gr.Column():
            # Components for user interaction
            name_input = gr.Textbox(label="Enter your name", placeholder="Your name")
            start_button = gr.Button("Start Quiz")
            question_label = gr.Textbox(label="Question", interactive=False)
            answer_input = gr.Textbox(label="Your Answer", placeholder="Type your answer here")
            submit_button = gr.Button("Submit")
            output_label = gr.Textbox(label="Result", interactive=False)
            quit_button = gr.Button("Quit")

            # Button click actions
            start_button.click(
                fn=start_quiz,
                inputs=[name_input],
                outputs=[question_label, gr.State(), gr.State(), gr.State(), gr.State()]
            )
            submit_button.click(
                fn=submit_answer,
                inputs=[answer_input, gr.State(), gr.State(), gr.State(), gr.State()],
                outputs=[output_label, question_label, gr.State(), gr.State(), gr.State()]
            )
            quit_button.click(
                fn=quit_quiz,
                inputs=[name_input, gr.State(), gr.State()],
                outputs=[output_label]
            )

    return app

app = gradio_interface()
app.launch()
